# %%
import pandas as pd
dataset=pd.read_csv("Quality data Preprocessed data.csv")

# %%
dataset
# Out:
#            Product        Time Equipment  Char A  Char B  Char C  Char D
# 0        Product-1  2022-09-05        B1      82      17      12     126  \
# 1        Product-2  2022-09-05        B1      96      13      13      72
# 2        Product-3  2022-09-05        B1      60      12      13      56
# 3        Product-4  2022-09-05        B1      53      12      11      45
# 4        Product-5  2022-09-05        B1      56      12      17      49
# ...            ...         ...       ...     ...     ...     ...     ...
# 5639  Product-5640  2023-04-20        B1      84       3      14      63
# 5640  Product-5641  2023-04-20        B4      52       2      12      42
# 5641  Product-5642  2023-04-20        B4      56       2       9      66
# 5642  Product-5643  2023-04-20        B1      51       3      13      67
# 5643  Product-5644  2023-04-20        B1      26       1       9      51
#
#       Char E Char A6 Char A7 Char A8 Char A9 Char A10 Class
# 0        119       B       C       A       H        H     H
# 1         42       B       B       A       B        B     B
# 2         33       B       B       A       B        B     B
# 3         21       B       B       A       B        A     B
# 4         26       B       B       B       B        A     B
# ...      ...     ...     ...     ...     ...      ...   ...
# 5639      61       B       A       B       B        C     C
# 5640      20       B       A       A       B        A     B
# 5641      39       B       A       A       B        B     B
# 5642      43       B       A       A       B        B     B
# 5643      18       A       A       A       B        A     B
#
# [5644 rows x 14 columns]

# %%
dataset['Time']
# Out:
# 0       2022-09-05
# 1       2022-09-05
# 2       2022-09-05
# 3       2022-09-05
# 4       2022-09-05
#            ...
# 5639    2023-04-20
# 5640    2023-04-20
# 5641    2023-04-20
# 5642    2023-04-20
# 5643    2023-04-20
# Name: Time, Length: 5644, dtype: object

# %%
dataset.columns
# Out:
# Index(['Product', 'Time', 'Equipment', 'Char A', 'Char B', 'Char C', 'Char D',
#        'Char E', 'Char A6', 'Char A7', 'Char A8', 'Char A9', 'Char A10',
#        'Class'],
#       dtype='object')

# %%
data = dataset['Time'].tolist()

# %%
start_date = pd.Timestamp('2022-09-05')
end_date = start_date + pd.DateOffset(hours=len(data) - 1)
index = pd.date_range(start=start_date, end=end_date, freq='H')
series = pd.Series(data=data, index=index)
index
# Out:
# DatetimeIndex(['2022-09-05 00:00:00', '2022-09-05 01:00:00',
#                '2022-09-05 02:00:00', '2022-09-05 03:00:00',
#                '2022-09-05 04:00:00', '2022-09-05 05:00:00',
#                '2022-09-05 06:00:00', '2022-09-05 07:00:00',
#                '2022-09-05 08:00:00', '2022-09-05 09:00:00',
#                ...
#                '2023-04-27 18:00:00', '2023-04-27 19:00:00',
#                '2023-04-27 20:00:00', '2023-04-27 21:00:00',
#                '2023-04-27 22:00:00', '2023-04-27 23:00:00',
#                '2023-04-28 00:00:00', '2023-04-28 01:00:00',
#                '2023-04-28 02:00:00', '2023-04-28 03:00:00'],
#               dtype='datetime64[ns]', length=5644, freq='H')

# %%
all_date=index

# %%
dummyDate=dataset

# %%
dummyDate.index=all_date

# %%
dummyDate
# Out:
#                           Product        Time Equipment  Char A  Char B
# 2022-09-05 00:00:00     Product-1  2022-09-05        B1      82      17  \
# 2022-09-05 01:00:00     Product-2  2022-09-05        B1      96      13
# 2022-09-05 02:00:00     Product-3  2022-09-05        B1      60      12
# 2022-09-05 03:00:00     Product-4  2022-09-05        B1      53      12
# 2022-09-05 04:00:00     Product-5  2022-09-05        B1      56      12
# ...                           ...         ...       ...     ...     ...
# 2023-04-27 23:00:00  Product-5640  2023-04-20        B1      84       3
# 2023-04-28 00:00:00  Product-5641  2023-04-20        B4      52       2
# 2023-04-28 01:00:00  Product-5642  2023-04-20        B4      56       2
# 2023-04-28 02:00:00  Product-5643  2023-04-20        B1      51       3
# 2023-04-28 03:00:00  Product-5644  2023-04-20        B1      26       1
#
#                      Char C  Char D  Char E Char A6 Char A7 Char A8 Char A9
# 2022-09-05 00:00:00      12     126     119       B       C       A       H  \
# 2022-09-05 01:00:00      13      72      42       B       B       A       B
# 2022-09-05 02:00:00      13      56      33       B       B       A       B
# 2022-09-05 03:00:00      11      45      21       B       B       A       B
# 2022-09-05 04:00:00      17      49      26       B       B       B       B
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2023-04-27 23:00:00      14      63      61       B       A       B       B
# 2023-04-28 00:00:00      12      42      20       B       A       A       B
# 2023-04-28 01:00:00       9      66      39       B       A       A       B
# 2023-04-28 02:00:00      13      67      43       B       A       A       B
# 2023-04-28 03:00:00       9      51      18       A       A       A       B
#
#                     Char A10 Class
# 2022-09-05 00:00:00        H     H
# 2022-09-05 01:00:00        B     B
# 2022-09-05 02:00:00        B     B
# 2022-09-05 03:00:00        A     B
# 2022-09-05 04:00:00        A     B
# ...                      ...   ...
# 2023-04-27 23:00:00        C     C
# 2023-04-28 00:00:00        A     B
# 2023-04-28 01:00:00        B     B
# 2023-04-28 02:00:00        B     B
# 2023-04-28 03:00:00        A     B
#
# [5644 rows x 14 columns]

# %%
dummyDate.columns
# Out:
# Index(['Product', 'Time', 'Equipment', 'Char A', 'Char B', 'Char C', 'Char D',
#        'Char E', 'Char A6', 'Char A7', 'Char A8', 'Char A9', 'Char A10',
#        'Class'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
plt.plot(dataset['Char A'])

# %%
from pandas import read_csv
from matplotlib import pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(dummyDate['Char A'], model='multiplicative')
plt.figure(figsize=(16,5))
result.plot()
plt.show()

# %%
from pandas import read_csv
from matplotlib import pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(dummyDate['Char A'], model='additive')
plt.figure(figsize=(16,5))
result.plot()
plt.show()

# %%
# ADF Test
# Function to print out results in customised manner
from statsmodels.tsa.stattools import adfuller
def adf_test(timeseries,df,pollutant):
    plt.figure(figsize=(16,5))
    # Plot the data
    # ADF Test
    # Function to print out results in customised manner
    from statsmodels.tsa.stattools import adfuller
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)
    ans=dfoutput
    print("Condition:")
    print("p-value<=0.05-->Accept Alternate Hypothesis")
    print("p-value>0.05-->Accept Null Hypothesis")
    if(ans['Test Statistic']<ans["Critical Value (1%)"] or ans['Test Statistic']<ans["Critical Value (5%)"] or ans['Test Statistic']<ans["Critical Value (10%)"] and ans["p-value"]<0.05):
        print("Condition: statictic < any critical value and p-value <0.05 to reject null hypothsis")
        print("Reject null hypothesis:Non Stationarity")
        print("Accept Alternate hypothesis:Staionarity ")
        message="Stationarity based on ADH"
    else:
        print("Condition: statictic < any critical value and p-value <0.05 to reject null hypothsis")
        print("Accept null hypothesis:Non Stationarity" )
        print("Reject Alternate hypothesis:Staionarity ")
        message="Non-stationarity based on ADH"
        
    plt.plot(df.index, df[pollutant], label = pollutant)
    plt.legend(loc='best')
    plt.title("{}_{}_2022 to 2023".format(message,pollutant))
    plt.savefig("{}_ADH.png".format(pollutant))
    plt.show()
    
    return message
    
# Call the function and run the test

# %%
adf_test(dataset['Char A'],dataset,'Char A')
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -8.855168e+00
# p-value                        1.534898e-14
# #Lags Used                     2.900000e+01
# Number of Observations Used    5.614000e+03
# Critical Value (1%)           -3.431515e+00
# Critical Value (5%)           -2.862055e+00
# Critical Value (10%)          -2.567044e+00
# dtype: float64
# Condition:
# p-value<=0.05-->Accept Alternate Hypothesis
# p-value>0.05-->Accept Null Hypothesis
# Condition: statictic < any critical value and p-value <0.05 to reject null hypothsis
# Reject null hypothesis:Non Stationarity
# Accept Alternate hypothesis:Staionarity
# 'Stationarity based on ADH'

# %%
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig, axes = plt.subplots(1,2,figsize=(16,3), dpi= 100)
plot_acf(dataset.Char A.tolist(), lags=50, ax=axes[0])
plot_pacf(dataset.Char A.tolist(), lags=50, ax=axes[1])
# Out:
#   Cell In[23], line 5
#     plot_acf(dataset.Char A.tolist(), lags=50, ax=axes[0])
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
plt.plot(acf(dataset["Close"],nlags=50))

# %%
acf(dataset["Close"]).sum()

# %%
pacf(dataset["Close"]).sum()

# %%
plt.plot(pacf(dataset["Close"],nlags=50))

# %%
from pandas.plotting import lag_plot
lag_plot(dataset["Close"],lag=1)

# %% [markdown]
# ## Forecastability
#
# ### Apen small- Forecastability is possible
# ### Spen Small-Forecastability is possible

# %%
def ApEn(U, m, r):
    """Compute Aproximate entropy"""
    def _maxdist(x_i, x_j):
        return max([abs(ua - va) for ua, va in zip(x_i, x_j)])

    def _phi(m):
        x = [[U[j] for j in range(i, i + m - 1 + 1)] for i in range(N - m + 1)]
        C = [len([1 for x_j in x if _maxdist(x_i, x_j) <= r]) / (N - m + 1.0) for x_i in x]
        return (N - m + 1.0)**(-1) * sum(np.log(C))

    N = len(U)
    return abs(_phi(m+1) - _phi(m))

# %%
import numpy as np
print(ApEn(dataset["Close"], m=2, r=0.2*np.std(dataset["Close"])))

# %%
def SampEn(U, m, r):
    """Compute Sample entropy"""
    def _maxdist(x_i, x_j):
        return max([abs(ua - va) for ua, va in zip(x_i, x_j)])

    def _phi(m):
        x = [[U[j] for j in range(i, i + m - 1 + 1)] for i in range(N - m + 1)]
        C = [len([1 for j in range(len(x)) if i != j and _maxdist(x[i], x[j]) <= r]) for i in range(len(x))]
        return sum(C)

    N = len(U)
    return -np.log(_phi(m+1) / _phi(m))

# %%
print(SampEn(dataset["Close"], m=2, r=0.2*np.std(dataset["Close"])))
